# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error
import pickle

# %%
path=r"C:\Users\prana\t20s"

# %%
filenames=[]
for file in os.listdir(path):
    filenames.append(os.path.join(path,file))

# %%
filenames[1:10]
# Out:
# ['C:\\Users\\prana\\t20s\\1001351.yaml',
#  'C:\\Users\\prana\\t20s\\1001353.yaml',
#  'C:\\Users\\prana\\t20s\\1004729.yaml',
#  'C:\\Users\\prana\\t20s\\1007655.yaml',
#  'C:\\Users\\prana\\t20s\\1007657.yaml',
#  'C:\\Users\\prana\\t20s\\1007659.yaml',
#  'C:\\Users\\prana\\t20s\\1019979.yaml',
#  'C:\\Users\\prana\\t20s\\1019981.yaml',
#  'C:\\Users\\prana\\t20s\\1019983.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
#   0%|                                                                                         | 0/1433 [00:00<?, ?it/s]C:\Users\prana\AppData\Local\Temp\ipykernel_54652\2042649833.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|                                                                                 | 1/1433 [00:00<19:55,  1.20it/s]C:\Users\prana\AppData\Local\Temp\ipykernel_54652\2042649833.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
backup = final_df.copy()

# %%
final_df.head()
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
#
#   meta.created  meta.revision    info.dates info.gender info.match_type  \
# 0   2017-02-18              2  [2017-02-17]        male             T20
# 0   2017-02-19              2  [2017-02-19]        male             T20
# 0   2017-02-23              1  [2017-02-22]        male             T20
# 0   2016-09-12              1  [2016-09-05]        male             T20
# 0   2016-06-19              1  [2016-06-18]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  ...  \
# ...

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.gender info.match_type info.outcome.winner  info.overs  \
# 0         male             T20           Sri Lanka          20
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# male      966
# female    466
# Name: info.gender, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_2856\2142223783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# ...

# %%
final_df['info.match_type'].value_counts()
# Out:
# T20    966
# Name: info.match_type, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    963
# 50      3
# Name: info.overs, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_2856\3157072726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))

# %%
matches.iloc[0]['innings'][0]['1st innings']['team']
# Out:
# 'Australia'

# %%
matches.iloc[0]['innings'][0]
# Out:
# {'1st innings': {'team': 'Australia',
#   'deliveries': [{0.1: {'batsman': 'AJ Finch',
#      'bowler': 'SL Malinga',
#      'non_striker': 'M Klinger',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.2: {'batsman': 'AJ Finch',
#      'bowler': 'SL Malinga',
#      'non_striker': 'M Klinger',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.3: {'batsman': 'AJ Finch',
#      'bowler': 'SL Malinga',
#      'non_striker': 'M Klinger',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {0.4: {'batsman': 'M Klinger',
#      'bowler': 'SL Malinga',
#      'non_striker': 'AJ Finch',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {0.5: {'batsman': 'M Klinger',
#      'bowler': 'SL Malinga',
#      'non_striker': 'AJ Finch',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.6: {'batsman': 'M Klinger',
#      'bowler': 'SL Malinga',
#      'non_striker': 'AJ Finch',
# ...

# %%
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.4: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.5: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {1.1: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_54652\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\prana\AppData\Local\Temp\ipykernel_54652\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\prana\AppData\Local\Temp\ipykernel_54652\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\prana\AppData\Local\Temp\ipykernel_54652\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# ...

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121       964  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       964  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       964  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       964  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       964  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue
# ...

# %%
def bowling_team(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowling_team,axis=1)

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121       964  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       964  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       964  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       964  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       964  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue  \
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies', 'Ireland',
#        'Afghanistan', 'Pakistan', 'United Arab Emirates', 'Scotland',
#        'Oman', 'Papua New Guinea', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania'],
#       dtype=object)

# %%
#Choosing only top 10 teams
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output.head(5)
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  NaN
# 1         2    Australia    Sri Lanka   0.2     0                0  NaN
# 2         2    Australia    Sri Lanka   0.3     1                0  NaN
# 3         2    Australia    Sri Lanka   0.4     2                0  NaN
# 4         2    Australia    Sri Lanka   0.5     0                0  NaN
#
#                       venue
# 0  Melbourne Cricket Ground
# 1  Melbourne Cricket Ground
# 2  Melbourne Cricket Ground
# 3  Melbourne Cricket Ground
# 4  Melbourne Cricket Ground

# %%
output['runs'].iloc[3]
# Out:
# 2

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 500].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\1598928411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df.head(5)
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\4047424117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\4047424117.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df[10:20]
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\285279089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#     match_id batting_team bowling_team  ball  runs player_dismissed  \
# 10         2    Australia    Sri Lanka   1.5     4                0
# 11         2    Australia    Sri Lanka   1.6     2                0
# 12         2    Australia    Sri Lanka   2.1     1                0
# 13         2    Australia    Sri Lanka   2.2     1                0
# 14         2    Australia    Sri Lanka   2.3     0                0
# 15         2    Australia    Sri Lanka   2.4     0                0
# ...

# %%
df['over'].astype('int')
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 121    19
# 122    19
# 123    19
# 124    19
# 125    19
# Name: over, Length: 53223, dtype: int32

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\540685528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\540685528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\540685528.py:3: SettingWithCopyWarning:
# ...

# %%
df.head(6)
# Out:
#    match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0         2    Australia    Sri Lanka   0.1     0                 0
# 1         2    Australia    Sri Lanka   0.2     0                 0
# 2         2    Australia    Sri Lanka   0.3     1                 0
# 3         2    Australia    Sri Lanka   0.4     2                 0
# 4         2    Australia    Sri Lanka   0.5     0                 0
# 5         2    Australia    Sri Lanka   0.6     3                 0
#
#         city  current_score over ball_no  balls_bowled  balls_left  \
# 0  Melbourne              0    0       1             1         119
# 1  Melbourne              0    0       2             2         118
# 2  Melbourne              1    0       3             3         117
# 3  Melbourne              3    0       4             4         116
# 4  Melbourne              3    0       5             5         115
# 5  Melbourne              6    0       6             6         114
#
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df.head(5)
# Out:
#    match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0         2    Australia    Sri Lanka   0.1     0                 0
# 1         2    Australia    Sri Lanka   0.2     0                 0
# 2         2    Australia    Sri Lanka   0.3     1                 0
# 3         2    Australia    Sri Lanka   0.4     2                 0
# 4         2    Australia    Sri Lanka   0.5     0                 0
#
#         city  current_score over ball_no  balls_bowled  balls_left  \
# 0  Melbourne              0    0       1             1         119
# 1  Melbourne              0    0       2             2         118
# 2  Melbourne              1    0       3             3         117
# 3  Melbourne              3    0       4             4         116
# 4  Melbourne              3    0       5             5         115
#
#    wickets_left  crr
# 0            10  0.0
# 1            10  0.0
# 2            10  2.0
# 3            10  4.5
# 4            10  3.6

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\3055083752.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_43976\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     168    Australia    Sri Lanka   0.1       0
# 1             2     168    Australia    Sri Lanka   0.2       0
# 2             2     168    Australia    Sri Lanka   0.3       1
# 3             2     168    Australia    Sri Lanka   0.4       2
# 4             2     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 53218       964     128    Sri Lanka    Australia  19.3       1
# 53219       964     128    Sri Lanka    Australia  19.4       0
# 53220       964     128    Sri Lanka    Australia  19.5       0
# 53221       964     128    Sri Lanka    Australia  19.6       2
# 53222       964     128    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city  current_score over ball_no  balls_bowled  \
# 0                     0  Melbourne              0    0       1             1
# ...

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12691
# runs_x               0
# dtype: int64

# %%
final_df=final_df.dropna()

# %%
#shuffling to reduce variance /bias

final_df = final_df.sample(final_df.shape[0])

# %%
from sklearn.model_selection import train_test_split
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train.shape
# Out:
# (32425, 8)

# %%
y_test.isna().sum()
# Out:
# 0

# %%
final_df['city'].unique()
# Out:
# array(['Centurion', 'Colombo', 'Cape Town', 'Auckland', 'Lucknow',
#        'Durban', 'Mirpur', 'Dubai', 'Barbados', 'Johannesburg',
#        'Christchurch', 'Sydney', 'Pallekele', 'Cardiff', 'Melbourne',
#        'Wellington', 'Kolkata', 'St Lucia', 'Hamilton', 'Adelaide',
#        'Nottingham', 'Manchester', 'Southampton', 'Birmingham',
#        'Trinidad', 'Nagpur', 'St Kitts', 'Bangalore', 'Abu Dhabi',
#        'London', 'Chandigarh', 'Lahore', 'Chittagong', 'Brisbane',
#        'Mumbai', 'Lauderhill', 'Delhi', 'Dhaka', 'Mount Maunganui',
#        'Hambantota'], dtype=object)

# %%
transformer=ColumnTransformer(transformers=[
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')

# %%
transformed_x=transformer.fit_transform(X_train)

# %%
transformed_x
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  7.        ,
#          5.35135135, 23.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  6.        ,
#          8.90721649, 48.        ],
#        [ 0.        ,  0.        ,  1.        , ...,  6.        ,
#          6.51923077, 40.        ],
#        ...,
#        [ 0.        ,  0.        ,  1.        , ...,  7.        ,
#          9.        , 60.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  8.        ,
#          7.95348837, 45.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  7.        ,
#          6.78947368, 39.        ]])

# %%
transformed_y=transformer.fit_transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaled_x=scaler.fit_transform(transformed_x)
scaled_y=scaler.fit_transform(transformed_y)

# %%
rfr=RandomForestRegressor()

# %%
rfr.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, KFold

# %%
# param = { 'criterion': ['squared_error', 'absolute_error', 'poisson'],
#     'max_depth': range(2,20,1),
#          'n_estimators': [90,100,115,130],
#          'max_features':['sqrt','log2']}

# %%
#grid_search_rfr = GridSearchCV(estimator=rfr,param_grid=param,cv=5,n_jobs =-1,verbose = 3)

# %%
 #grid_search_rfr.fit(transformed_x, y_train)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits

# %%
rfr = RandomForestRegressor(criterion= 'squared_error',
 max_depth = 12,
 max_features = 'log2',
 min_samples_leaf = 1,
 min_samples_split= 5,
 n_estimators = 90,random_state=6)

# %%
rfr.fit(scaled_x,y_train)
# Out:
# RandomForestRegressor(max_depth=12, max_features='log2', min_samples_split=5,
#                       n_estimators=90, random_state=6)

# %%
y_pred = rfr.predict(scaled_y)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.7411880816496705
# 12.038217875054857

# %%
rfr_1 = RandomForestRegressor(criterion= 'absolute_error',
 max_depth = 12,
 max_features = 'sqrt',
 min_samples_leaf = 1,
 min_samples_split= 5,
 n_estimators = 90,random_state=6)

# %%
rfr_1.fit(scaled_x,y_train)
# Out:
# RandomForestRegressor(criterion='absolute_error', max_depth=12,
#                       max_features='sqrt', min_samples_split=5, n_estimators=90,
#                       random_state=6)

# %%
y_pred_1 = rfr_1.predict(scaled_y)
print(r2_score(y_test,y_pred_1))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.7521132185937233
# 12.038217875054857

# %%
xg_boost=XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1)

# %%
xg_boost.fit(scaled_x,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=1000,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=1,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred_xg = rfr.predict(scaled_y)
print(r2_score(y_test,y_pred_xg))
print(mean_absolute_error(y_test,y_pred_xg))
# Out:
# 0.7411880816496705
# 12.038217875054857

# %%
##Looks like rfr_1 is giving best accuracy ,although it can be improved with hyperparameter tuning ,didn't perform it here bcoz its taking long time

# %%
pickle.dump(rfr_1,open('t20.pkl','wb'))

# %%
scaled_y.shape
# Out:
# (8107, 62)

# %%
pickle.dump(xg_boost,open('t20_xg.pkl','wb'))

# %%
scaled_y[5]
# Out:
# array([ 2.93350477, -0.23198094, -0.31338773, -0.35492566, -0.39329228,
#        -0.39579759, -0.37275129, -0.38001308, -0.34179014, -0.39224623,
#        -0.28067024,  2.59674324, -0.34917165, -0.3395351 , -0.38973034,
#        -0.32973532, -0.34246496, -0.33817785, -0.10946928, -0.22389626,
#        -0.10713766,  4.81663783, -0.09727965, -0.10713766, -0.21304946,
#        -0.10354639, -0.15281587, -0.10772508, -0.13730013, -0.11004482,
#        -0.2974561 , -0.10713766, -0.09792365, -0.24975417, -0.16856921,
#        -0.10535666, -0.153238  , -0.25390852, -0.12665745, -0.11455007,
#        -0.15196841, -0.20304641, -0.09532252, -0.14369102, -0.17911303,
#        -0.25909798, -0.12615382, -0.14635119, -0.11565034, -0.13542306,
#        -0.19738129, -0.14007203, -0.10475656, -0.17652919, -0.17049426,
#        -0.1029362 , -0.16386714, -0.57891932, -0.07857104, -0.39078255,
#        -1.19217563, -0.47050784])

# %%
rfr_1.predict(np.array([ 2.93350477, -0.23198094, -0.31338773, -0.35492566, -0.39329228,
       -0.39579759, -0.37275129, -0.38001308, -0.34179014, -0.39224623,
       -0.28067024,  2.59674324, -0.34917165, -0.3395351 , -0.38973034,
       -0.32973532, -0.34246496, -0.33817785, -0.10946928, -0.22389626,
       -0.10713766,  4.81663783, -0.09727965, -0.10713766, -0.21304946,
       -0.10354639, -0.15281587, -0.10772508, -0.13730013, -0.11004482,
       -0.2974561 , -0.10713766, -0.09792365, -0.24975417, -0.16856921,
       -0.10535666, -0.153238  , -0.25390852, -0.12665745, -0.11455007,
       -0.15196841, -0.20304641, -0.09532252, -0.14369102, -0.17911303,
       -0.25909798, -0.12615382, -0.14635119, -0.11565034, -0.13542306,
       -0.19738129, -0.14007203, -0.10475656, -0.17652919, -0.17049426,
       -0.1029362 , -0.16386714, -0.57891932, -0.07857104, -0.39078255,
       -1.19217563, -0.47050784]).reshape(1,62))
# Out:
# array([143.74444444])

# %%
rfr_1.predict(np.array(scaled_y[5]).reshape(1,62))
# Out:
# array([143.74444444])

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3', RandomForestRegressor(criterion= 'absolute_error',
 max_depth = 12,
 max_features = 'sqrt',
 min_samples_leaf = 1,
 min_samples_split= 5,
 n_estimators = 90,random_state=6))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.7519636284461997
# 11.303973246714087

# %%
pickle.dump(rfr_1,open('pipe.pkl','wb'))
